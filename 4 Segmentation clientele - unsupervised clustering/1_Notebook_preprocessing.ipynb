# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customers = pd.read_csv('olist_customers_dataset.csv')
geolocalisation = pd.read_csv('olist_geolocation_dataset.csv')
items = pd.read_csv('olist_order_items_dataset.csv', parse_dates=[4])
payments = pd.read_csv('olist_order_payments_dataset.csv')
reviews = pd.read_csv('olist_order_reviews_dataset.csv', parse_dates=[5,6])
orders = pd.read_csv('olist_orders_dataset.csv', parse_dates=[3,4,5,6,7])
products = pd.read_csv('olist_products_dataset.csv')
sellers = pd.read_csv('olist_sellers_dataset.csv')
prod_categorie = pd.read_csv('product_category_name_translation.csv')

# %% [markdown]
# # Sommaire <a class='anchor' id='S'></a>
#
# ## [I, Création du DF à partir de la base client](#I)
# ### [A, Fusion de items et orders](#IA)
# ### [B, Fusion du df avec products, reviews et customers](#IB)
# ### [C, Nettoyage des colonnes inutiles](#IC)
# ### [D, Sélection d'une période cohérente](#ID)
#
# # [II, Transformation des données avec client en clé](#II)
# ### [A, Extraction des composantes](#IIA)
# ### [B, Réunion des composantes](#IIB)
#
# # [III, Analyses](#III)
# ## [A, Première analyse](#IIIA)
# ## [B, Détection d'outliers avec Isolation Forest](#IIIB)
# ## [C, Sélection des features pertinentes](#IIIC)
#
# ##### [fin de page](#fdp)

# %%
customers.head(2)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP

# %%
customers.shape
# Out:
# (99441, 5)

# %%
geolocalisation.head(2)
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP

# %%
geolocalisation.shape
# Out:
# (1000163, 5)

# %%
items.head(2)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
#
#   shipping_limit_date  price  freight_value
# 0 2017-09-19 09:45:35   58.9          13.29
# 1 2017-05-03 11:05:13  239.9          19.93

# %%
items.shape
# Out:
# (112650, 7)

# %%
payments.head(2)
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39

# %%
payments.shape
# Out:
# (103886, 5)

# %%
reviews.head(2)
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
#
#    review_score review_comment_title review_comment_message  \
# 0             4                  NaN                    NaN
# 1             5                  NaN                    NaN
#
#   review_creation_date review_answer_timestamp
# 0           2018-01-18     2018-01-18 21:46:59
# 1           2018-03-10     2018-03-11 03:05:13

# %%
reviews.shape
# Out:
# (100000, 7)

# %%
orders.head(2)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
#
#   order_estimated_delivery_date
# 0                    2017-10-18
# 1                    2018-08-13

# %%
orders.shape
# Out:
# (99441, 8)

# %%
products.head(2)
# Out:
#                          product_id product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5            perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                 artes
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0

# %%
products.shape
# Out:
# (32951, 9)

# %%
sellers.head(2)
# Out:
#                           seller_id  seller_zip_code_prefix seller_city  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023    campinas
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844  mogi guacu
#
#   seller_state
# 0           SP
# 1           SP

# %%
sellers.shape
# Out:
# (3095, 4)

# %%
prod_categorie.head(2)
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories

# %%
prod_categorie.shape
# Out:
# (71, 2)

# %% [markdown]
# ##### [sommaire](#S)

# %% [markdown]
# # I, Création du DF à partir de la base client <a class='anchor' id='I'></a>

# %% [markdown]
# ## A, Fusion de items et orders <a class='anchor' id='IA'></a>

# %% [markdown]
# Pour regrouper les données, nous allons partir du df items, qui comprend le détail de chaque commande, sachant qu'une commande peut contenir plusieurs achats.<br/>
# Nous allons fusionner ce df avec celui des orders et des products.

# %%
# les commandes contenant plus d'un produit
items[items.duplicated('order_id')].shape
# Out:
# (13984, 7)

# %%
len(items.order_id.unique())
# Out:
# 98666

# %%
print("Items shape :",items.shape)
print("orders shape :",orders.shape)
# Out:
# Items shape : (112650, 7)
# orders shape : (99441, 8)

# %%
df = items.merge(orders, how='left', on='order_id')

# %%
print("df shape :",df.shape)
# Out:
# df shape : (112650, 14)

# %% [markdown]
# Nouveau DF a des valeurs nulles, la plupart concernan t des commandes en cours et non-finalisées.<br/>
# Mais on note également certaines erreurs.

# %%
df.isna().sum()
# Out:
# order_id                            0
# order_item_id                       0
# product_id                          0
# seller_id                           0
# shipping_limit_date                 0
# price                               0
# freight_value                       0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                  15
# order_delivered_carrier_date     1194
# order_delivered_customer_date    2454
# order_estimated_delivery_date       0
# dtype: int64

# %%
df[df.order_delivered_customer_date.isna()].order_status.unique()
# Out:
# array(['shipped', 'canceled', 'invoiced', 'processing', 'delivered',
#        'approved', 'unavailable'], dtype=object)

# %%
df[(df.order_delivered_customer_date.isna()) & (df.order_status == 'delivered')]
# Out:
#                                 order_id  order_item_id  \
# 5841    0d3268bad9b086af767785e3f0fc0133              1
# 14472   20edc82cf5400ce95e1afacc25798b31              1
# 19642   2d1e2d5bf4dc7227b3bfebb81328c15f              1
# 19838   2d858f451373b04fb5c984a1cc2defaf              1
# 20393   2ebdfc4f15f23b91474edf87475f108e              1
# 75303   ab7c89dc1bf4a1ead9d6ec1ec8968a84              1
# 101642  e69f75a717d64fc5ecdfae42b2e8e086              1
# 108192  f5dd62b788049ad9fc0526e3ad11a097              1
#
#                               product_id                         seller_id  \
# 5841    ec165cd31c50585786ffda6feff5d0a6  8bdd8e3fd58bafa48af76b2c5fd71974
# 14472   55bfa0307d7a46bed72c492259921231  343e716476e3748b069f980efbaa294e
# 19642   a50acd33ba7a8da8e9db65094fa990a4  8581055ce74af1daba164fdbd55a40de
# 19838   30b5b5635a79548a48d04162d971848f  f9bbdd976532d50b7816d285a22bd01e
# 20393   e7d5464b94c9a5963f7c686fc80145ad  58f1a6197ed863543e0136bdedb3fce2
# 75303   a2a7efc985315e86d4f0f705701b342b  ed4acab38528488b65a9a9c603ff024a
# 101642  e7d5464b94c9a5963f7c686fc80145ad  58f1a6197ed863543e0136bdedb3fce2
# 108192  2167c8f6252667c0eb9edd51520706a1  0bb738e4d789e63e2267697c42d35a2d
#
#        shipping_limit_date   price  freight_value  \
# 5841   2018-07-05 21:29:54  188.99          15.63
# 14472  2018-07-03 16:29:30   45.90           9.07
# 19642  2017-12-04 17:56:40  117.30          17.53
# 19838  2017-06-04 23:30:16  179.00          15.00
# 20393  2018-07-05 17:15:12  139.00          19.07
# 75303  2018-06-18 12:30:35  110.99           9.13
# 101642 2018-07-05 22:15:14  139.00          19.07
# 108192 2018-06-26 07:19:05  329.00          25.24
#
#                              customer_id order_status  \
# 5841    4f1d63d35fb7c8999853b2699f5c7649    delivered
# 14472   28c37425f1127d887d7337f284080a0f    delivered
# 19642   ec05a6d8558c6455f0cbbd8a420ad34f    delivered
# 19838   e08caf668d499a6d643dafd7c5cc498a    delivered
# 20393   29f0540231702fda0cfdee0a310f11aa    delivered
# 75303   dd1b84a7286eb4524d52af4256c0ba24    delivered
# 101642  cfda40ca8dd0a5d486a9635b611b398a    delivered
# 108192  5e89028e024b381dc84a13a3570decb4    delivered
#
#        order_purchase_timestamp   order_approved_at  \
# 5841        2018-07-01 21:14:02 2018-07-01 21:29:54
# 14472       2018-06-27 16:09:12 2018-06-27 16:29:30
# 19642       2017-11-28 17:44:07 2017-11-28 17:56:40
# 19838       2017-05-25 23:22:43 2017-05-25 23:30:16
# 20393       2018-07-01 17:05:11 2018-07-01 17:15:12
# 75303       2018-06-08 12:09:39 2018-06-08 12:36:39
# 101642      2018-07-01 22:05:55 2018-07-01 22:15:14
# 108192      2018-06-20 06:58:43 2018-06-20 07:19:05
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# 5841            2018-07-03 09:28:00                           NaT
# 14472           2018-07-03 19:26:00                           NaT
# 19642           2017-11-30 18:12:23                           NaT
# 19838                           NaT                           NaT
# 20393           2018-07-03 13:57:00                           NaT
# 75303           2018-06-12 14:10:00                           NaT
# 101642          2018-07-03 13:57:00                           NaT
# 108192          2018-06-25 08:05:00                           NaT
#
#        order_estimated_delivery_date
# 5841                      2018-07-24
# 14472                     2018-07-19
# 19642                     2017-12-18
# 19838                     2017-06-23
# 20393                     2018-07-30
# 75303                     2018-06-26
# 101642                    2018-07-30
# 108192                    2018-07-16

# %%
# Temporalité du jeu de données, la donnée la plus récente est :
df.order_purchase_timestamp.max()
# Out:
# Timestamp('2018-09-03 09:06:57')

# %%
# 1er tri dans les colonnes

df = df.drop(['order_approved_at', 'order_delivered_carrier_date', 'shipping_limit_date', 'order_estimated_delivery_date'], axis=1)

# %% [markdown]
# ##### [sommaire](#S)

# %% [markdown]
# ## B, Fusion du df avec products, reviews et customers <a class='anchor' id='IB'></a>

# %% [markdown]
# ### Fusion avec product

# %% [markdown]
# Ensuite, nous allons fusionner ce df avec product, reviews et customer.

# %%
print("df shape :",df.shape)
print("products shape :",products.shape)
print("reviews shape :",reviews.shape)
print("customers shape :",customers.shape)
# Out:
# df shape : (112650, 10)
# products shape : (32951, 9)
# reviews shape : (100000, 7)
# customers shape : (99441, 5)

# %%
prod = products.loc[:,['product_id', 'product_category_name']]

# %%
df = df.merge(prod, how='left', on='product_id')

# %%
df.shape
# Out:
# (112650, 11)

# %% [markdown]
# ### Fusion avec reviews

# %%
reviews.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       88285
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
reviews = reviews.drop('review_answer_timestamp', axis=1)

# %%
df = df.merge(reviews, how='left', on='order_id')

# %%
df.isna().sum()
# Out:
# order_id                             0
# order_item_id                        0
# product_id                           0
# seller_id                            0
# price                                0
# freight_value                        0
# customer_id                          0
# order_status                         0
# order_purchase_timestamp             0
# order_delivered_customer_date     2475
# product_category_name             1612
# review_id                            0
# review_score                         0
# review_comment_title             99700
# review_comment_message           64730
# review_creation_date                 0
# dtype: int64

# %%
df.shape
# Out:
# (113322, 16)

# %% [markdown]
# On note que le df fusionné avec reviews contient 672 lignes de plus qu'avant. Cela signifie que certaines commandes on plusieurs avis **pour le même produit**.<br/>

# %%
df[df.duplicated(subset=['order_id', 'order_item_id'])].shape
# Out:
# (672, 16)

# %%
liste = df[df.duplicated(subset=['order_id', 'order_item_id'])].order_id.unique()

# %%
len(liste)
# Out:
# 552

# %%
prov_initial = df[df.order_id.isin(liste)]

# %%
prov_initial.shape
# Out:
# (1338, 16)

# %%
prov = prov_initial.copy()

# %%
# On garde la ligne avec le plus d'informations
for i in prov.order_id.unique():
    temp = prov[prov.order_id == i]
    for j in temp.order_item_id:
        temp = temp[temp.order_item_id == j]
        temp = temp[~(temp.isna().sum(axis=1) == temp.isna().sum(axis=1).min())]
        prov = prov[~prov.index.isin(temp.index)]
print(prov.shape)
# Out:
# (1229, 16)

# %%
# On garde la ligne la plus récente
for i in prov.order_id.unique():
    temp = prov[prov.order_id == i]
    for j in temp.order_item_id:
        temp = temp[temp.order_item_id == j]
        temp = temp[~(temp.review_creation_date == temp.review_creation_date.max())]
        prov = prov[~prov.index.isin(temp.index)]
    
print(prov.shape)
# Out:
# (917, 16)

# %%
# Les doublons qui restent peuvent êtr considérés comme de "vrai doublons, donc nous les supprimons"

prov = prov.drop_duplicates(subset=['order_id', 'order_item_id'], keep='last')

print(prov.shape)
# Out:
# (666, 16)

# %%
df2 = df[~df.index.isin(prov_initial.index)]

# %%
df2.shape
# Out:
# (111984, 16)

# %%
df2 = pd.concat([df2, prov])

# %%
df2.shape
# Out:
# (112650, 16)

# %%
df = df2.copy()

# %% [markdown]
# ### Fusion avec customers

# %%
df.shape
# Out:
# (112650, 16)

# %%
df = df.merge(customers, how='left', on='customer_id')

# %%
df.shape
# Out:
# (112650, 20)

# %%
df.isna().sum()
# Out:
# order_id                             0
# order_item_id                        0
# product_id                           0
# seller_id                            0
# price                                0
# freight_value                        0
# customer_id                          0
# order_status                         0
# order_purchase_timestamp             0
# order_delivered_customer_date     2454
# product_category_name             1603
# review_id                            0
# review_score                         0
# review_comment_title             99045
# review_comment_message           64244
# review_creation_date                 0
# customer_unique_id                   0
# customer_zip_code_prefix             0
# customer_city                        0
# customer_state                       0
# dtype: int64

# %% [markdown]
# ### Fusion avec payments

# %%
pay_type = payments.copy()

# %%
pay_type = pay_type.loc[:,['order_id', 'payment_type']]

# %%
pay_type = pay_type.drop_duplicates('order_id')

# %%
pay_type.head(2)
# Out:
#                            order_id payment_type
# 0  b81ef226f3fe1789b1e8b2acac839d17  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0  credit_card

# %%
df = df.merge(pay_type, how='left', on='order_id')

# %%
df.shape
# Out:
# (112650, 21)

# %%
df.isna().sum()
# Out:
# order_id                             0
# order_item_id                        0
# product_id                           0
# seller_id                            0
# price                                0
# freight_value                        0
# customer_id                          0
# order_status                         0
# order_purchase_timestamp             0
# order_delivered_customer_date     2454
# product_category_name             1603
# review_id                            0
# review_score                         0
# review_comment_title             99045
# review_comment_message           64244
# review_creation_date                 0
# customer_unique_id                   0
# customer_zip_code_prefix             0
# customer_city                        0
# customer_state                       0
# payment_type                         3
# dtype: int64

# %%
df[df.payment_type.isna()]
# Out:
#                                order_id  order_item_id  \
# 83876  bfbd0f9bdef84302105ad712db648a6c              1
# 83877  bfbd0f9bdef84302105ad712db648a6c              2
# 83878  bfbd0f9bdef84302105ad712db648a6c              3
#
#                              product_id                         seller_id  \
# 83876  5a6b04657a4c5ee34285d1e4619a96b4  ecccfa2bb93b34a3bf033cc5d1dcdc69
# 83877  5a6b04657a4c5ee34285d1e4619a96b4  ecccfa2bb93b34a3bf033cc5d1dcdc69
# 83878  5a6b04657a4c5ee34285d1e4619a96b4  ecccfa2bb93b34a3bf033cc5d1dcdc69
#
#        price  freight_value                       customer_id order_status  \
# 83876  44.99           2.83  86dc2ffce2dfff336de2f386a786e574    delivered
# 83877  44.99           2.83  86dc2ffce2dfff336de2f386a786e574    delivered
# 83878  44.99           2.83  86dc2ffce2dfff336de2f386a786e574    delivered
#
#       order_purchase_timestamp order_delivered_customer_date  ...  \
# 83876      2016-09-15 12:16:38           2016-11-09 07:47:38  ...
# 83877      2016-09-15 12:16:38           2016-11-09 07:47:38  ...
# 83878      2016-09-15 12:16:38           2016-11-09 07:47:38  ...
#
#                               review_id review_score  review_comment_title  \
# 83876  6916ca4502d6d3bfd39818759d55d536            1                   NaN
# 83877  6916ca4502d6d3bfd39818759d55d536            1                   NaN
# 83878  6916ca4502d6d3bfd39818759d55d536            1                   NaN
#
#                                review_comment_message review_creation_date  \
# 83876  nao recebi o produto e nem resposta da empresa           2016-10-06
# 83877  nao recebi o produto e nem resposta da empresa           2016-10-06
# 83878  nao recebi o produto e nem resposta da empresa           2016-10-06
#
#                      customer_unique_id customer_zip_code_prefix  \
# 83876  830d5b7aaa3b6f1e9ad63703bec97d23                    14600
# 83877  830d5b7aaa3b6f1e9ad63703bec97d23                    14600
# 83878  830d5b7aaa3b6f1e9ad63703bec97d23                    14600
#
#               customer_city customer_state payment_type
# 83876  sao joaquim da barra             SP          NaN
# 83877  sao joaquim da barra             SP          NaN
# 83878  sao joaquim da barra             SP          NaN
#
# [3 rows x 21 columns]

# %% [markdown]
# ##### [sommaire](#S)

# %% [markdown]
# ## C, Nettoyage des colonnes inutiles <a class='anchor' id='IC'></a>

# %%
df.isna().sum()
# Out:
# order_id                             0
# order_item_id                        0
# product_id                           0
# seller_id                            0
# price                                0
# freight_value                        0
# customer_id                          0
# order_status                         0
# order_purchase_timestamp             0
# order_delivered_customer_date     2454
# product_category_name             1603
# review_id                            0
# review_score                         0
# review_comment_title             99045
# review_comment_message           64244
# review_creation_date                 0
# customer_unique_id                   0
# customer_zip_code_prefix             0
# customer_city                        0
# customer_state                       0
# payment_type                         3
# dtype: int64

# %%
data = df.drop(['order_id', 'order_item_id', 'product_id', 'seller_id', 'customer_id', 'review_id', 
         'review_creation_date', 'customer_zip_code_prefix', 'customer_city', 'review_comment_title',
                'review_comment_message', 'freight_value'], axis=1)

# %% [markdown]
# #### On ne garde que les commandes livrées

# %%
data.order_status.unique()
# Out:
# array(['delivered', 'shipped', 'canceled', 'invoiced', 'processing',
#        'approved', 'unavailable'], dtype=object)

# %%
data.order_status.value_counts()
# Out:
# delivered      110197
# shipped          1185
# canceled          542
# invoiced          359
# processing        357
# unavailable         7
# approved            3
# Name: order_status, dtype: int64

# %%
data = data[data.order_status == 'delivered']

# %%
data = data.drop('order_status', axis=1)

# %% [markdown]
# #### On écarte les données manquantes pour les colonnes paiement et catégorie de produits

# %%
data = data[~data.payment_type.isna()]

# %%
data.isna().sum()
# Out:
# price                               0
# order_purchase_timestamp            0
# order_delivered_customer_date       8
# product_category_name            1537
# review_score                        0
# customer_unique_id                  0
# customer_state                      0
# payment_type                        0
# dtype: int64

# %%
data = data[~data.product_category_name.isna()]

# %%
data.reset_index(drop=True, inplace=True)

# %%
data.head(2)
# Out:
#    price order_purchase_timestamp order_delivered_customer_date  \
# 0   58.9      2017-09-13 08:59:02           2017-09-20 23:43:48
# 1  239.9      2017-04-26 10:53:06           2017-05-12 16:04:24
#
#   product_category_name  review_score                customer_unique_id  \
# 0            cool_stuff             5  871766c5855e863f6eccc05f988b23cb
# 1              pet_shop             4  eb28e67c4c0b83846050ddfb8a35d051
#
#   customer_state payment_type
# 0             RJ  credit_card
# 1             SP  credit_card

# %% [markdown]
# ##### [sommaire](#S)

# %% [markdown]
# ## D, Séléction d'une période cohérente <a class='anchor' id='ID'></a>

# %%
data.order_purchase_timestamp.max()
# Out:
# Timestamp('2018-08-29 15:00:37')

# %%
data.order_purchase_timestamp.min()
# Out:
# Timestamp('2016-10-03 09:44:50')

# %%
import datetime as dt

plt.figure(figsize=(12,4))
sns.histplot(x='order_purchase_timestamp', data=data)
plt.ylim(0,5000)
plt.xticks(rotation=60)
#plt.savefig("repartition_des_données_dans_le_temps.png", bbox_inches='tight', transparent=True)
plt.show()

# %% [markdown]
# On voit que l'on dispose de très peu de données sur l'année 2016.
# Aussi, pour pouvoir effectuer une analyse pertinente sur une temporalité cohérente, nous allons travailler sur l'année 2017.

# %%
df = data[(data.order_purchase_timestamp >= '2017-01-01') & (data.order_purchase_timestamp <= '2017-12-31')]

# %%
df.shape
# Out:
# (48611, 8)

# %%
data.to_csv('data_regroupee.csv')

# %% [markdown]
# ##### [sommaire](#S)

# %% [markdown]
# # II, Transformation des données avec client en clé <a class='anchor' id='II'></a>

# %% [markdown]
# ## A, Extraction des composantes <a class='anchor' id='IIA'></a>

# %%
# Création d'une date de positionnement à partir de delivery date
from datetime import timedelta

snapshot_date = df.order_delivered_customer_date.max() + timedelta(days=1)
print(snapshot_date)
# Out:
# 2018-05-22 18:22:18

# %% [markdown]
# #### Composantes temporelles

# %%
duree = df.pivot_table(index='customer_unique_id', values='order_purchase_timestamp', aggfunc=['min', 'max'], dropna=False)

# %%
duree['time_since_first_purchase_(days)'] = (snapshot_date - duree['min']['order_purchase_timestamp']).dt.days
duree['time_since_last_purchase_(days)'] = (snapshot_date - duree['max']['order_purchase_timestamp']).dt.days

# %%
duree['date_first_purchase'] = duree['min']['order_purchase_timestamp']
duree['date_last_purchase'] = duree['max']['order_purchase_timestamp']
duree = duree.iloc[:,4:]
duree.columns = duree.columns.get_level_values(0)

# %%
duree.head(2)
# Out:
#                                  date_first_purchase  date_last_purchase
# customer_unique_id
# 0000f46a3911fa3c0805444483337064 2017-03-10 21:05:03 2017-03-10 21:05:03
# 0000f6ccb0745a6a4b88665a16c9f078 2017-10-12 20:29:41 2017-10-12 20:29:41

# %%
df2 = df.copy()

# %%
df2['delivery_time'] = (df2.order_delivered_customer_date - df2.order_purchase_timestamp).dt.days

# %%
delivery = df2.pivot_table(index='customer_unique_id', values='delivery_time', aggfunc='mean')

# %%
delivery.head(2)
# Out:
#                                   delivery_time
# customer_unique_id
# 0000f46a3911fa3c0805444483337064           25.0
# 0000f6ccb0745a6a4b88665a16c9f078           20.0

# %% [markdown]
# #### Composantes monétaires

# %%
prix = df.pivot_table(index='customer_unique_id', values='price', aggfunc=['min', 'max', 'sum'], dropna=False)

# %%
prix['min_purchase_amount'] = prix['min']['price']
prix['max_purchase_amount'] = prix['max']['price']
prix['total_purchase_amount'] = prix['sum']['price']
prix = prix.iloc[:,3:]
prix.columns = prix.columns.get_level_values(0)

# %%
prix
# Out:
#                                   min_purchase_amount  max_purchase_amount  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                69.00                69.00
# 0000f6ccb0745a6a4b88665a16c9f078                25.99                25.99
# 0004aac84e0df4da2b147fca70cf8255               180.00               180.00
# 0005e1862207bf6ccc02e4228effd9a0               135.00               135.00
# 0006fdc98a402fceb4eb0ee528f6a8d4                13.90                13.90
# ...                                               ...                  ...
# fffb09418989a0dbff854a28163e47c6                58.00                58.00
# fffcf5a5ff07b0908bd4e2dbc735a684               680.00               890.00
# fffea47cd6d3cc0a88bd621562a9d061                64.89                64.89
# ffff371b4d645b6ecea244b27531430a                89.90                89.90
# ffffd2657e2aad2907e67c3e9daecbeb                56.99                56.99
#
#                                   total_purchase_amount
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                  69.00
# 0000f6ccb0745a6a4b88665a16c9f078                  25.99
# 0004aac84e0df4da2b147fca70cf8255                 180.00
# 0005e1862207bf6ccc02e4228effd9a0                 135.00
# 0006fdc98a402fceb4eb0ee528f6a8d4                  13.90
# ...                                                 ...
# fffb09418989a0dbff854a28163e47c6                  58.00
# fffcf5a5ff07b0908bd4e2dbc735a684                1570.00
# fffea47cd6d3cc0a88bd621562a9d061                  64.89
# ffff371b4d645b6ecea244b27531430a                  89.90
# ffffd2657e2aad2907e67c3e9daecbeb                  56.99
#
# [41354 rows x 3 columns]

# %% [markdown]
# #### Composantes sur les avis

# %%
avis = df.pivot_table(index='customer_unique_id', values='review_score', aggfunc=['count', 'mean'], dropna=False)

# %%
avis.columns = ["_".join(col).strip() for col in avis.columns.values]

# %%
avis.head(2)
# Out:
#                                   count_review_score  mean_review_score
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                   1                3.0
# 0000f6ccb0745a6a4b88665a16c9f078                   1                4.0

# %% [markdown]
# #### Composantes sur les catégories

# %%
df2['cat_count'] = 1

# %%
cat_prod = df2.pivot_table(index='customer_unique_id', columns='product_category_name', values='cat_count', aggfunc='sum', margins='all', margins_name='total_purchase_count')
cat_prod = cat_prod.iloc[:-1,:]
cat_prod = cat_prod.fillna(0)

# %%
liste = []
for i in cat_prod.index:
    temp = cat_prod.loc[i,:]
    liste.append(temp[temp == temp.max()].index[0])

# %%
cat_prod['item_most_purchase'] = liste

# %%
cat_prod = cat_prod.iloc[:,-2:]

# %%
cat_prod.head(2)
# Out:
# product_category_name             total_purchase_count item_most_purchase
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                     1          papelaria
# 0000f6ccb0745a6a4b88665a16c9f078                     1          telefonia

# %% [markdown]
# #### Autres composantes

# %%
liste = ['customer_unique_id', 'customer_state', 'payment_type']

# %%
autre = df.loc[:,liste]

# %%
autre = autre.drop_duplicates(subset='customer_unique_id')

# %% [markdown]
# ##### [sommaire](#S)

# %% [markdown]
# ## B, Réunion des composantes <a class='anchor' id='IIB'></a>

# %%
df = pd.concat([duree, delivery, prix, avis, cat_prod], axis=1)

# %%
df = pd.merge(df, autre, how='left', on='customer_unique_id')

# %%
df.isna().sum()
# Out:
# customer_unique_id       0
# date_first_purchase      0
# date_last_purchase       0
# delivery_time            2
# min_purchase_amount      0
# max_purchase_amount      0
# total_purchase_amount    0
# count_review_score       0
# mean_review_score        0
# total_purchase_count     0
# item_most_purchase       0
# customer_state           0
# payment_type             0
# dtype: int64

# %%
df.delivery_time.mean()
# Out:
# 12.56335589830946

# %%
df = df.fillna(12)

# %%
df.head(2)
# Out:
#                  customer_unique_id date_first_purchase  date_last_purchase  \
# 0  0000f46a3911fa3c0805444483337064 2017-03-10 21:05:03 2017-03-10 21:05:03
# 1  0000f6ccb0745a6a4b88665a16c9f078 2017-10-12 20:29:41 2017-10-12 20:29:41
#
#    delivery_time  min_purchase_amount  max_purchase_amount  \
# 0           25.0                69.00                69.00
# 1           20.0                25.99                25.99
#
#    total_purchase_amount  count_review_score  mean_review_score  \
# 0                  69.00                   1                3.0
# 1                  25.99                   1                4.0
#
#    total_purchase_count item_most_purchase customer_state payment_type
# 0                     1          papelaria             SC  credit_card
# 1                     1          telefonia             PA  credit_card

# %% [markdown]
# ##### [sommaire](#S)

# %% [markdown]
# # III, Analyses <a class='anchor' id='III'></a>

# %%
df.set_index('customer_unique_id', drop=True, inplace=True)

# %% [markdown]
# ## A, Première analyse <a class='anchor' id='IIIA'></a>

# %%
df.dtypes
# Out:
# date_first_purchase      datetime64[ns]
# date_last_purchase       datetime64[ns]
# delivery_time                   float64
# min_purchase_amount             float64
# max_purchase_amount             float64
# total_purchase_amount           float64
# count_review_score                int64
# mean_review_score               float64
# total_purchase_count              int64
# item_most_purchase               object
# customer_state                   object
# payment_type                     object
# dtype: object

# %%
for c in df.columns:
    if c == 'customer_unique_id':
        continue
    if (df[c].dtypes == 'float64') | (df[c].dtypes == 'int64'):
        f, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,2))
        plt.subplots_adjust(wspace=0.5)
        plt.suptitle('Analyse univarié de {}'.format(c), fontsize=15, y=1.1)
        g1 = sns.boxplot(x=c, data=df, ax=ax[0])
        g1.vlines(df[c].mean(), ymin=-0.4, ymax=0.4, color='darkred')
        g1.set(xlabel=None)
        g2 = sns.histplot(x=c, data=df, ax=ax[1])
        g2.set(xlabel=None)
        #plt.savefig("analyse_univariee_"+c+".png", bbox_inches='tight', transparent=True)
        plt.show()
    else:
        f, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,2))
        plt.subplots_adjust(wspace=0.5)
        plt.suptitle('Analyse univarié de {}'.format(c), fontsize=15, y=1.1)
        g1 = sns.histplot(x=c, data=df, ax=ax[0])
        plt.setp(ax[0].xaxis.get_majorticklabels(), rotation=90)
        g1.set(xlabel=None, ylabel=None)
        if ('time' in c) | ('date' in c):
            temp = pd.DataFrame(df[c].dt.date.value_counts())
            temp = temp.iloc[:10,:] 
        else:
            temp = pd.DataFrame(df[c].value_counts())
            temp = temp.iloc[:10,:]
        g2 = sns.barplot(x=c, y=temp.index, data=temp, ax=ax[1])
        #plt.savefig("analyse_univariee_"+c+".png", bbox_inches='tight', transparent=True)
        plt.show()

# %%
amount = []
for c in df.columns:
    if 'amount' in c:
        amount.append(c)
amount = df.loc[:,amount]

# %%
for c in amount.columns:
    f, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,2))
    plt.suptitle('Analyse univarié de {}'.format(c), fontsize=15, y=1.1)
    g1 = sns.boxplot(x=c, data=amount, ax=ax[0])
    g1.vlines(amount[c].mean(), ymin=-0.4, ymax=0.4, color='darkred')
    g1.set(xlabel=None)
    g2 = sns.histplot(x=c, data=amount,log_scale=True, ax=ax[1])
    g2.set(xlabel=None)
    #plt.savefig("analyse_univariee_log_"+c+".png", bbox_inches='tight', transparent=True)
    plt.show()

# %% [markdown]
# ##### [sommaire](#S)

# %% [markdown]
# ## B, Détection d'outliers avec Isolation Forest <a class='anchor' id='IIIB'></a>

# %%
df_if = df.copy()

# %%
df_if.reset_index(inplace=True)

# %%
df_if2 = df_if.copy()

# %%
df_if.drop(['customer_unique_id', 'date_first_purchase', 'date_last_purchase'], inplace=True, axis=1)

# %%
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import LabelEncoder

# %%
ifr = IsolationForest(bootstrap=True, contamination=0.1)

# %%
for c in df_if.columns:
    if df_if[c].dtypes == 'object':
        le = LabelEncoder()
        df_if[c] = le.fit_transform(df_if[c])

# %%
df_if2['iforest'] = ifr.fit_predict(df_if)

# %%
df_if2.iforest.value_counts()
# Out:
#  1    37218
# -1     4136
# Name: iforest, dtype: int64

# %%
df_if2 = df_if2[df_if2.iforest == 1]

# %%
df_if2 = df_if2.drop('iforest', axis=1)

# %%
df_if2.set_index('customer_unique_id', inplace=True)

# %%
for c in df_if2.columns:
    if c == 'customer_unique_id':
        continue
    if (df_if2[c].dtypes == 'float64') | (df_if2[c].dtypes == 'int64'):
        f, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,2))
        plt.subplots_adjust(wspace=0.5)
        plt.suptitle('Analyse univarié de {}'.format(c), fontsize=15, y=1.1)
        g1 = sns.boxplot(x=c, data=df_if2, ax=ax[0])
        g1.vlines(df_if2[c].mean(), ymin=-0.4, ymax=0.4, color='darkred')
        g1.set(xlabel=None)
        g2 = sns.histplot(x=c, data=df_if2, ax=ax[1])
        g2.set(xlabel=None)
        #plt.savefig("analyse_univariee_IFR_"+c+".png", bbox_inches='tight', transparent=True)
        plt.show()
    else:
        f, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,2))
        plt.subplots_adjust(wspace=0.5)
        plt.suptitle('Analyse univarié de {}'.format(c), fontsize=15, y=1.1)
        g1 = sns.histplot(x=c, data=df_if2, ax=ax[0])
        plt.setp(ax[0].xaxis.get_majorticklabels(), rotation=90)
        g1.set(xlabel=None, ylabel=None)
        if ('time' in c) | ('date' in c):
            temp = pd.DataFrame(df_if2[c].dt.date.value_counts())
            temp = temp.iloc[:10,:] 
        else:
            temp = pd.DataFrame(df_if2[c].value_counts())
            temp = temp.iloc[:10,:]
        g2 = sns.barplot(x=c, y=temp.index, data=temp, ax=ax[1])
        #plt.savefig("analyse_univariee_IFR_"+c+".png", bbox_inches='tight', transparent=True)
        plt.show()

# %% [markdown]
# ##### [sommaire](#S)

# %% [markdown]
# ## C, Sélection des features pertinentes <a class='anchor' id='IIIC'></a>

# %% [markdown]
# Si on applique une segmentation RFM stricte, on gardera les colonnes :
# - date last purchase (recency)
# - total purchase count (frequency)
# - total purchase amount (monetary)
#
# Cependant, pour ne pas perdre trop d'informations, nous allons garder d'autres features tels que :
# - delivery time (durée de la livraison)
# - mean review score
# - item most purchase
# - customer state
# - payment type

# %%
df_if2.shape
# Out:
# (37218, 8)

# %%
df_if2 = df_if2.drop(['date_first_purchase', 'min_purchase_amount', 'max_purchase_amount', 'count_review_score'], axis=1)

# %%
df_if2.head(2)
# Out:
#                                   date_last_purchase  delivery_time  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064 2017-03-10 21:05:03           25.0
# 0000f6ccb0745a6a4b88665a16c9f078 2017-10-12 20:29:41           20.0
#
#                                   total_purchase_amount  mean_review_score  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                  69.00                3.0
# 0000f6ccb0745a6a4b88665a16c9f078                  25.99                4.0
#
#                                   total_purchase_count item_most_purchase  \
# customer_unique_id
# 0000f46a3911fa3c0805444483337064                     1          papelaria
# 0000f6ccb0745a6a4b88665a16c9f078                     1          telefonia
#
#                                  customer_state payment_type
# customer_unique_id
# 0000f46a3911fa3c0805444483337064             SC  credit_card
# 0000f6ccb0745a6a4b88665a16c9f078             PA  credit_card

# %%
df_if2.to_csv('df_if2.csv')

# %%
df[df.total_purchase_amount >1000]
# Out:
#                                  date_first_purchase  date_last_purchase  \
# customer_unique_id
# 00adeda9b742746c0c66e10d00ea1b74 2017-11-07 16:54:04 2017-11-07 16:54:04
# 011875f0176909c5cf0b14a9138bb691 2017-03-18 20:08:04 2017-03-18 20:08:04
# 019ac5580a897d52e5ed6f7ed89ade27 2017-09-06 09:49:37 2017-09-06 09:49:37
# 0228e299d1cabeaf9be64b5ccd784c97 2017-07-21 13:24:01 2017-07-21 13:24:01
# 0326524848da9311350236471586bd61 2017-03-01 11:44:37 2017-03-01 11:44:37
# ...                                              ...                 ...
# ff0ae98646e7bbb41cf0f0d3991fef98 2017-06-05 20:52:34 2017-06-05 20:52:34
# ff0e4a6f3114ad1d211b885159bf1eb2 2017-04-01 10:44:01 2017-04-01 10:44:01
# ff4159b92c40ebe40454e3e6a7c35ed6 2017-05-24 18:14:34 2017-05-24 18:14:34
# ffba9f9dff87b05e310ecc46c8591044 2017-02-27 15:39:41 2017-02-27 15:39:41
# fffcf5a5ff07b0908bd4e2dbc735a684 2017-06-08 21:00:36 2017-06-08 21:00:36
#
#                                   delivery_time  min_purchase_amount  \
# customer_unique_id
# 00adeda9b742746c0c66e10d00ea1b74            7.0               629.00
# 011875f0176909c5cf0b14a9138bb691            5.0              3999.90
# 019ac5580a897d52e5ed6f7ed89ade27           12.0               429.00
# 0228e299d1cabeaf9be64b5ccd784c97           16.0              1099.00
# 0326524848da9311350236471586bd61           18.0              1800.00
# ...                                         ...                  ...
# ff0ae98646e7bbb41cf0f0d3991fef98           10.0              2999.89
# ff0e4a6f3114ad1d211b885159bf1eb2            4.0              1654.44
# ff4159b92c40ebe40454e3e6a7c35ed6           11.0              6499.00
# ffba9f9dff87b05e310ecc46c8591044           15.0              1591.20
# fffcf5a5ff07b0908bd4e2dbc735a684           27.0               680.00
#
#                                   max_purchase_amount  total_purchase_amount  \
# customer_unique_id
# 00adeda9b742746c0c66e10d00ea1b74              1449.50                2078.50
# 011875f0176909c5cf0b14a9138bb691              3999.90                3999.90
# 019ac5580a897d52e5ed6f7ed89ade27               429.00                1287.00
# 0228e299d1cabeaf9be64b5ccd784c97              1099.00                1099.00
# 0326524848da9311350236471586bd61              1800.00                1800.00
# ...                                               ...                    ...
# ff0ae98646e7bbb41cf0f0d3991fef98              2999.89                2999.89
# ff0e4a6f3114ad1d211b885159bf1eb2              1654.44                1654.44
# ff4159b92c40ebe40454e3e6a7c35ed6              6499.00                6499.00
# ffba9f9dff87b05e310ecc46c8591044              1591.20                1591.20
# fffcf5a5ff07b0908bd4e2dbc735a684               890.00                1570.00
#
#                                   count_review_score  mean_review_score  \
# customer_unique_id
# 00adeda9b742746c0c66e10d00ea1b74                   2                1.0
# 011875f0176909c5cf0b14a9138bb691                   1                5.0
# 019ac5580a897d52e5ed6f7ed89ade27                   3                5.0
# 0228e299d1cabeaf9be64b5ccd784c97                   1                5.0
# 0326524848da9311350236471586bd61                   1                5.0
# ...                                              ...                ...
# ff0ae98646e7bbb41cf0f0d3991fef98                   1                5.0
# ff0e4a6f3114ad1d211b885159bf1eb2                   1                5.0
# ff4159b92c40ebe40454e3e6a7c35ed6                   1                5.0
# ffba9f9dff87b05e310ecc46c8591044                   1                5.0
# fffcf5a5ff07b0908bd4e2dbc735a684                   2                5.0
#
#                                   total_purchase_count  \
# customer_unique_id
# 00adeda9b742746c0c66e10d00ea1b74                     2
# 011875f0176909c5cf0b14a9138bb691                     1
# 019ac5580a897d52e5ed6f7ed89ade27                     3
# 0228e299d1cabeaf9be64b5ccd784c97                     1
# 0326524848da9311350236471586bd61                     1
# ...                                                ...
# ff0ae98646e7bbb41cf0f0d3991fef98                     1
# ff0e4a6f3114ad1d211b885159bf1eb2                     1
# ff4159b92c40ebe40454e3e6a7c35ed6                     1
# ffba9f9dff87b05e310ecc46c8591044                     1
# fffcf5a5ff07b0908bd4e2dbc735a684                     2
#
#                                       item_most_purchase customer_state  \
# customer_unique_id
# 00adeda9b742746c0c66e10d00ea1b74      relogios_presentes             SP
# 011875f0176909c5cf0b14a9138bb691      relogios_presentes             SP
# 019ac5580a897d52e5ed6f7ed89ade27           esporte_lazer             SP
# 0228e299d1cabeaf9be64b5ccd784c97      relogios_presentes             MT
# 0326524848da9311350236471586bd61           esporte_lazer             SP
# ...                                                  ...            ...
# ff0ae98646e7bbb41cf0f0d3991fef98  informatica_acessorios             BA
# ff0e4a6f3114ad1d211b885159bf1eb2      relogios_presentes             SP
# ff4159b92c40ebe40454e3e6a7c35ed6                   artes             SP
# ffba9f9dff87b05e310ecc46c8591044      relogios_presentes             PA
# fffcf5a5ff07b0908bd4e2dbc735a684            beleza_saude             PE
#
#                                  payment_type
# customer_unique_id
# 00adeda9b742746c0c66e10d00ea1b74  credit_card
# 011875f0176909c5cf0b14a9138bb691  credit_card
# 019ac5580a897d52e5ed6f7ed89ade27       boleto
# 0228e299d1cabeaf9be64b5ccd784c97  credit_card
# 0326524848da9311350236471586bd61       boleto
# ...                                       ...
# ff0ae98646e7bbb41cf0f0d3991fef98  credit_card
# ff0e4a6f3114ad1d211b885159bf1eb2       boleto
# ff4159b92c40ebe40454e3e6a7c35ed6       boleto
# ffba9f9dff87b05e310ecc46c8591044  credit_card
# fffcf5a5ff07b0908bd4e2dbc735a684  credit_card
#
# [427 rows x 12 columns]

# %%
df_if2.total_purchase_amount.describe()
# Out:
# count    37218.000000
# mean       103.359559
# std         84.441551
# min          2.290000
# 25%         44.990000
# 50%         79.900000
# 75%        135.000000
# max        610.000000
# Name: total_purchase_amount, dtype: float64

# %%
df[df.total_purchase_amount > 610]
# Out:
#                                  date_first_purchase  date_last_purchase  \
# customer_unique_id
# 0096c18412349537abc45e350581cbbc 2017-03-14 17:33:28 2017-03-14 17:33:28
# 00adeda9b742746c0c66e10d00ea1b74 2017-11-07 16:54:04 2017-11-07 16:54:04
# 00bee19e1199bc5cede1c674177b9e22 2017-11-17 19:42:27 2017-11-17 19:42:27
# 011875f0176909c5cf0b14a9138bb691 2017-03-18 20:08:04 2017-03-18 20:08:04
# 0199360d5869b53eece5870f3bd1ef0e 2017-05-21 08:05:33 2017-05-21 08:05:33
# ...                                              ...                 ...
# ff54194b7b7f32a428aff086b73bdf94 2017-10-08 21:42:35 2017-10-08 21:42:35
# ffba9f9dff87b05e310ecc46c8591044 2017-02-27 15:39:41 2017-02-27 15:39:41
# ffdffea8a4b04f14987bfef2a2287fa9 2017-09-13 11:04:08 2017-09-13 11:04:08
# ffebb6424578e7bb153322da9d65634f 2017-01-16 14:04:11 2017-01-16 14:04:11
# fffcf5a5ff07b0908bd4e2dbc735a684 2017-06-08 21:00:36 2017-06-08 21:00:36
#
#                                   delivery_time  min_purchase_amount  \
# customer_unique_id
# 0096c18412349537abc45e350581cbbc            7.0                169.9
# 00adeda9b742746c0c66e10d00ea1b74            7.0                629.0
# 00bee19e1199bc5cede1c674177b9e22           25.0                649.9
# 011875f0176909c5cf0b14a9138bb691            5.0               3999.9
# 0199360d5869b53eece5870f3bd1ef0e            4.0                740.0
# ...                                         ...                  ...
# ff54194b7b7f32a428aff086b73bdf94           17.0                679.9
# ffba9f9dff87b05e310ecc46c8591044           15.0               1591.2
# ffdffea8a4b04f14987bfef2a2287fa9            5.0                887.0
# ffebb6424578e7bb153322da9d65634f           37.0                629.0
# fffcf5a5ff07b0908bd4e2dbc735a684           27.0                680.0
#
#                                   max_purchase_amount  total_purchase_amount  \
# customer_unique_id
# 0096c18412349537abc45e350581cbbc                169.9                  679.6
# 00adeda9b742746c0c66e10d00ea1b74               1449.5                 2078.5
# 00bee19e1199bc5cede1c674177b9e22                649.9                  649.9
# 011875f0176909c5cf0b14a9138bb691               3999.9                 3999.9
# 0199360d5869b53eece5870f3bd1ef0e                740.0                  740.0
# ...                                               ...                    ...
# ff54194b7b7f32a428aff086b73bdf94                679.9                  679.9
# ffba9f9dff87b05e310ecc46c8591044               1591.2                 1591.2
# ffdffea8a4b04f14987bfef2a2287fa9                887.0                  887.0
# ffebb6424578e7bb153322da9d65634f                629.0                  629.0
# fffcf5a5ff07b0908bd4e2dbc735a684                890.0                 1570.0
#
#                                   count_review_score  mean_review_score  \
# customer_unique_id
# 0096c18412349537abc45e350581cbbc                   4                1.0
# 00adeda9b742746c0c66e10d00ea1b74                   2                1.0
# 00bee19e1199bc5cede1c674177b9e22                   1                3.0
# 011875f0176909c5cf0b14a9138bb691                   1                5.0
# 0199360d5869b53eece5870f3bd1ef0e                   1                5.0
# ...                                              ...                ...
# ff54194b7b7f32a428aff086b73bdf94                   1                5.0
# ffba9f9dff87b05e310ecc46c8591044                   1                5.0
# ffdffea8a4b04f14987bfef2a2287fa9                   1                5.0
# ffebb6424578e7bb153322da9d65634f                   1                1.0
# fffcf5a5ff07b0908bd4e2dbc735a684                   2                5.0
#
#                                   total_purchase_count     item_most_purchase  \
# customer_unique_id
# 0096c18412349537abc45e350581cbbc                     4  utilidades_domesticas
# 00adeda9b742746c0c66e10d00ea1b74                     2     relogios_presentes
# 00bee19e1199bc5cede1c674177b9e22                     1             cool_stuff
# 011875f0176909c5cf0b14a9138bb691                     1     relogios_presentes
# 0199360d5869b53eece5870f3bd1ef0e                     1           beleza_saude
# ...                                                ...                    ...
# ff54194b7b7f32a428aff086b73bdf94                     1     relogios_presentes
# ffba9f9dff87b05e310ecc46c8591044                     1     relogios_presentes
# ffdffea8a4b04f14987bfef2a2287fa9                     1                  bebes
# ffebb6424578e7bb153322da9d65634f                     1             cool_stuff
# fffcf5a5ff07b0908bd4e2dbc735a684                     2           beleza_saude
#
#                                  customer_state payment_type
# customer_unique_id
# 0096c18412349537abc45e350581cbbc             RS  credit_card
# 00adeda9b742746c0c66e10d00ea1b74             SP  credit_card
# 00bee19e1199bc5cede1c674177b9e22             GO  credit_card
# 011875f0176909c5cf0b14a9138bb691             SP  credit_card
# 0199360d5869b53eece5870f3bd1ef0e             RS  credit_card
# ...                                         ...          ...
# ff54194b7b7f32a428aff086b73bdf94             AL  credit_card
# ffba9f9dff87b05e310ecc46c8591044             PA  credit_card
# ffdffea8a4b04f14987bfef2a2287fa9             SP  credit_card
# ffebb6424578e7bb153322da9d65634f             SP  credit_card
# fffcf5a5ff07b0908bd4e2dbc735a684             PE  credit_card
#
# [1131 rows x 12 columns]

# %%
data[data.price > 500]
# Out:
#           price order_purchase_timestamp order_delivered_customer_date  \
# 7        810.00      2018-07-04 12:08:27           2018-07-09 14:04:07
# 16       639.00      2018-04-25 09:10:41           2018-04-30 17:54:25
# 39       809.10      2017-04-06 22:16:10           2017-05-23 08:32:07
# 151      540.00      2018-03-08 16:01:59           2018-03-20 22:27:30
# 256      579.00      2018-05-25 09:47:21           2018-06-07 00:18:30
# ...         ...                      ...                           ...
# 108291  1150.00      2017-11-25 15:48:04           2017-12-08 17:26:55
# 108429   599.99      2018-04-29 23:57:11           2018-05-04 22:31:59
# 108440   535.00      2017-08-29 11:34:11           2017-09-13 20:40:10
# 108563   525.00      2017-06-11 13:29:42           2017-06-21 15:48:45
# 108612  1054.00      2018-04-09 22:58:05           2018-04-16 15:48:28
#
#               product_category_name  review_score  \
# 7                ferramentas_jardim             5
# 16                   consoles_games             4
# 39           informatica_acessorios             1
# 151              relogios_presentes             5
# 256     portateis_casa_forno_e_cafe             4
# ...                             ...           ...
# 108291        utilidades_domesticas             5
# 108429           relogios_presentes             3
# 108440               consoles_games             4
# 108563           ferramentas_jardim             5
# 108612             eletrodomesticos             5
#
#                       customer_unique_id customer_state payment_type
# 7       fda4476abb6307ab3c415b7e6d026526             SP  credit_card
# 16      6062db572f3ef38b7a8ff4307abbfad3             SP  credit_card
# 39      98758d88bf4b8eef1372ddee45d63178             AL  credit_card
# 151     96fab6e511253d619ab79a63c31b29c4             SP       boleto
# 256     ead67853687963974dfd6a3c23072deb             MG  credit_card
# ...                                  ...            ...          ...
# 108291  4e1cce07cd5937c69dacac3c8b13d965             SP  credit_card
# 108429  e271fa40aa8fea4e0f304b3768b65d6a             SP  credit_card
# 108440  fed1227e08fb9852b896221a0932ffeb             SP  credit_card
# 108563  f16a7418dca2619d9524be10babfeb5f             GO  credit_card
# 108612  6ddbc64bd04d40f7768ff088d94cbeb8             SP       boleto
#
# [3063 rows x 8 columns]

# %% [markdown]
# ##### [sommaire](#S)

# %% [markdown]
# ##### fin de page <a class='anchor' id='fdp'></a>
